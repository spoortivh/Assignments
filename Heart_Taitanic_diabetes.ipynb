# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ###   DIABETES

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# ...                        ...  ...      ...
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0
#
# [2000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# min       0.000000                  0.078000    21.000000     0.000000
# 25%      27.375000                  0.244000    24.000000     0.000000
# 50%      32.300000                  0.376000    29.000000     0.000000
# 75%      36.800000                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000

# %%
df.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
X = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.805

# %%
model1 = GaussianNB()
model1.fit(X_train,y_train)
y_pred = model1.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.795

# %%
model2 = SVC()
model2.fit(X_train,y_train)
y_pred = model2.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7883333333333333

# %%
model3 = DecisionTreeClassifier()
model3.fit(X_train,y_train)
y_pred = model3.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9566666666666667

# %%
model4 = KNeighborsClassifier()
model4.fit(X_train,y_train)
y_pred = model4.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7716666666666666

# %% [markdown]
# ### Heart

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = df[['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']]
y = df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model10=LogisticRegression()
model10.fit(X_train,y_train)
y_pred = model10.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# C:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8131868131868132

# %%
model11 = GaussianNB()
model11.fit(X_train,y_train)
y_pred = model11.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8351648351648352

# %%
model22 = SVC()
model22.fit(X_train,y_train)
y_pred = model22.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7032967032967034

# %%
model33 = DecisionTreeClassifier()
model33.fit(X_train,y_train)
y_pred = model33.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7362637362637363

# %%
model44 = KNeighborsClassifier()
model44.fit(X_train,y_train)
y_pred = model44.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.6593406593406593

# %% [markdown]
# ### cross

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(SVC(),X,y,cv=5)
# Out:
# array([0.60655738, 0.60655738, 0.73770492, 0.68333333, 0.58333333])

# %%
cross_val_score(SVC(C=10,gamma="auto",kernel="linear"),X,y,cv=5)
# Out:
# array([0.7704918 , 0.91803279, 0.7704918 , 0.86666667, 0.76666667])

# %% [markdown]
# ## Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(SVC(),
                 {
                     'C':[1,2,5,9,10],
                     'kernel':['rbf','linear'],
                     'gamma':['scale','auto']
                 }, cv=4,return_train_score=False)
gs.fit(X,y)
# Out:
# GridSearchCV(cv=4, estimator=SVC(),
#              param_grid={'C': [1, 2, 5, 9, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']})

# %%
gs.cv_results_
# Out:
# {'mean_fit_time': array([3.99583578e-03, 1.22087306e+00, 1.17166042e-02, 1.06616372e+00,
#         0.00000000e+00, 1.10219407e+00, 1.34708881e-02, 8.24538112e-01,
#         1.24609470e-03, 4.30023724e+00, 1.17166042e-02, 4.27633995e+00,
#         0.00000000e+00, 2.95633864e+00, 3.90535593e-03, 2.80655849e+00,
#         7.81089067e-03, 3.84039873e+00, 3.90505791e-03, 3.80379748e+00]),
#  'std_fit_time': array([2.55143075e-03, 5.23615619e-01, 6.76458462e-03, 6.18406215e-01,
#         0.00000000e+00, 6.39933183e-01, 5.11678572e-04, 4.10362238e-01,
#         2.15829934e-03, 3.35462577e+00, 6.76458461e-03, 3.27619421e+00,
#         0.00000000e+00, 8.92796644e-01, 6.76427489e-03, 1.43469283e+00,
#         7.81089068e-03, 2.02398913e+00, 6.76375870e-03, 1.56193665e+00]),
#  'mean_score_time': array([0.01527375, 0.00490123, 0.03124166, 0.        , 0.01562214,
#         0.00490481, 0.03166032, 0.00049847, 0.01095533, 0.00781232,
#         0.03124207, 0.        , 0.01562124, 0.00781572, 0.01171166,
#         0.00390494, 0.02343112, 0.00099742, 0.01171607, 0.        ]),
#  'std_score_time': array([5.83208004e-03, 6.40047659e-03, 6.07850494e-07, 0.00000000e+00,
#         1.28392334e-06, 6.40191525e-03, 4.22013681e-04, 8.63381678e-04,
#         6.73008007e-03, 7.81232139e-03, 1.60268899e-06, 0.00000000e+00,
#         7.22667912e-07, 7.81572051e-03, 6.76173075e-03, 6.76355223e-03,
#         7.81196373e-03, 1.72758926e-03, 6.76427560e-03, 0.00000000e+00]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 2, 2, 2, 2, 5, 5, 5, 5, 9, 9, 9, 9, 10, 10,
#                     10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=['scale', 'scale', 'auto', 'auto', 'scale', 'scale',
#                     'auto', 'auto', 'scale', 'scale', 'auto', 'auto',
#                     'scale', 'scale', 'auto', 'auto', 'scale', 'scale',
#                     'auto', 'auto'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 2, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 2, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 9, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 9, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 9, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 9, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}],
#  'split0_test_score': array([0.60526316, 0.85526316, 0.55263158, 0.85526316, 0.64473684,
#         0.85526316, 0.55263158, 0.85526316, 0.63157895, 0.84210526,
#         0.55263158, 0.84210526, 0.64473684, 0.81578947, 0.55263158,
#         0.81578947, 0.64473684, 0.81578947, 0.55263158, 0.81578947]),
#  'split1_test_score': array([0.69736842, 0.88157895, 0.53947368, 0.88157895, 0.71052632,
#         0.88157895, 0.53947368, 0.88157895, 0.72368421, 0.86842105,
#         0.53947368, 0.86842105, 0.72368421, 0.85526316, 0.53947368,
#         0.85526316, 0.72368421, 0.85526316, 0.53947368, 0.85526316]),
#  'split2_test_score': array([0.64473684, 0.85526316, 0.53947368, 0.85526316, 0.67105263,
#         0.85526316, 0.53947368, 0.85526316, 0.67105263, 0.84210526,
#         0.53947368, 0.84210526, 0.68421053, 0.82894737, 0.53947368,
#         0.82894737, 0.68421053, 0.82894737, 0.53947368, 0.82894737]),
#  'split3_test_score': array([0.65333333, 0.77333333, 0.54666667, 0.77333333, 0.65333333,
#         0.8       , 0.56      , 0.8       , 0.65333333, 0.81333333,
#         0.56      , 0.81333333, 0.65333333, 0.81333333, 0.56      ,
#         0.81333333, 0.68      , 0.81333333, 0.56      , 0.81333333]),
#  'mean_test_score': array([0.65017544, 0.84135965, 0.5445614 , 0.84135965, 0.66991228,
#         0.84802632, 0.54789474, 0.84802632, 0.66991228, 0.84149123,
#         0.54789474, 0.84149123, 0.67649123, 0.82833333, 0.54789474,
#         0.82833333, 0.68315789, 0.82833333, 0.54789474, 0.82833333]),
#  'std_test_score': array([0.03272553, 0.04071789, 0.00550749, 0.04071789, 0.02529557,
#         0.02973655, 0.00881481, 0.02973655, 0.03404786, 0.01948613,
#         0.00881481, 0.01948613, 0.03094913, 0.01664287, 0.00881481,
#         0.01664287, 0.02797159, 0.01664287, 0.00881481, 0.01664287]),
#  'rank_test_score': array([15,  5, 20,  5, 13,  1, 16,  1, 13,  3, 16,  3, 12,  7, 16,  7, 11,
#          7, 16,  7])}

# %%
df1 = pd.DataFrame(gs.cv_results_)
df1
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.003996      0.002551         0.015274    5.832080e-03       1
# 1        1.220873      0.523616         0.004901    6.400477e-03       1
# 2        0.011717      0.006765         0.031242    6.078505e-07       1
# 3        1.066164      0.618406         0.000000    0.000000e+00       1
# 4        0.000000      0.000000         0.015622    1.283923e-06       2
# 5        1.102194      0.639933         0.004905    6.401915e-03       2
# 6        0.013471      0.000512         0.031660    4.220137e-04       2
# 7        0.824538      0.410362         0.000498    8.633817e-04       2
# 8        0.001246      0.002158         0.010955    6.730080e-03       5
# 9        4.300237      3.354626         0.007812    7.812321e-03       5
# 10       0.011717      0.006765         0.031242    1.602689e-06       5
# 11       4.276340      3.276194         0.000000    0.000000e+00       5
# 12       0.000000      0.000000         0.015621    7.226679e-07       9
# 13       2.956339      0.892797         0.007816    7.815721e-03       9
# 14       0.003905      0.006764         0.011712    6.761731e-03       9
# 15       2.806558      1.434693         0.003905    6.763552e-03       9
# 16       0.007811      0.007811         0.023431    7.811964e-03      10
# 17       3.840399      2.023989         0.000997    1.727589e-03      10
# 18       0.003905      0.006764         0.011716    6.764276e-03      10
# 19       3.803797      1.561937         0.000000    0.000000e+00      10
#
#    param_gamma param_kernel                                           params  \
# 0        scale          rbf      {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 1        scale       linear   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 2         auto          rbf       {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 3         auto       linear    {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 4        scale          rbf      {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# 5        scale       linear   {'C': 2, 'gamma': 'scale', 'kernel': 'linear'}
# 6         auto          rbf       {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# 7         auto       linear    {'C': 2, 'gamma': 'auto', 'kernel': 'linear'}
# 8        scale          rbf      {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 9        scale       linear   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 10        auto          rbf       {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 11        auto       linear    {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 12       scale          rbf      {'C': 9, 'gamma': 'scale', 'kernel': 'rbf'}
# 13       scale       linear   {'C': 9, 'gamma': 'scale', 'kernel': 'linear'}
# 14        auto          rbf       {'C': 9, 'gamma': 'auto', 'kernel': 'rbf'}
# 15        auto       linear    {'C': 9, 'gamma': 'auto', 'kernel': 'linear'}
# 16       scale          rbf     {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 17       scale       linear  {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 18        auto          rbf      {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 19        auto       linear   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.605263           0.697368           0.644737
# 1            0.855263           0.881579           0.855263
# 2            0.552632           0.539474           0.539474
# 3            0.855263           0.881579           0.855263
# 4            0.644737           0.710526           0.671053
# 5            0.855263           0.881579           0.855263
# 6            0.552632           0.539474           0.539474
# 7            0.855263           0.881579           0.855263
# 8            0.631579           0.723684           0.671053
# 9            0.842105           0.868421           0.842105
# 10           0.552632           0.539474           0.539474
# 11           0.842105           0.868421           0.842105
# 12           0.644737           0.723684           0.684211
# 13           0.815789           0.855263           0.828947
# 14           0.552632           0.539474           0.539474
# 15           0.815789           0.855263           0.828947
# 16           0.644737           0.723684           0.684211
# 17           0.815789           0.855263           0.828947
# 18           0.552632           0.539474           0.539474
# 19           0.815789           0.855263           0.828947
#
#     split3_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.653333         0.650175        0.032726               15
# 1            0.773333         0.841360        0.040718                5
# 2            0.546667         0.544561        0.005507               20
# 3            0.773333         0.841360        0.040718                5
# 4            0.653333         0.669912        0.025296               13
# 5            0.800000         0.848026        0.029737                1
# 6            0.560000         0.547895        0.008815               16
# 7            0.800000         0.848026        0.029737                1
# 8            0.653333         0.669912        0.034048               13
# 9            0.813333         0.841491        0.019486                3
# 10           0.560000         0.547895        0.008815               16
# 11           0.813333         0.841491        0.019486                3
# 12           0.653333         0.676491        0.030949               12
# 13           0.813333         0.828333        0.016643                7
# 14           0.560000         0.547895        0.008815               16
# 15           0.813333         0.828333        0.016643                7
# 16           0.680000         0.683158        0.027972               11
# 17           0.813333         0.828333        0.016643                7
# 18           0.560000         0.547895        0.008815               16
# 19           0.813333         0.828333        0.016643                7

# %%
df1[['param_C','param_gamma','param_kernel','mean_test_score']]
# Out:
#    param_C param_gamma param_kernel  mean_test_score
# 0        1       scale          rbf         0.650175
# 1        1       scale       linear         0.841360
# 2        1        auto          rbf         0.544561
# 3        1        auto       linear         0.841360
# 4        2       scale          rbf         0.669912
# 5        2       scale       linear         0.848026
# 6        2        auto          rbf         0.547895
# 7        2        auto       linear         0.848026
# 8        5       scale          rbf         0.669912
# 9        5       scale       linear         0.841491
# 10       5        auto          rbf         0.547895
# 11       5        auto       linear         0.841491
# 12       9       scale          rbf         0.676491
# 13       9       scale       linear         0.828333
# 14       9        auto          rbf         0.547895
# 15       9        auto       linear         0.828333
# 16      10       scale          rbf         0.683158
# 17      10       scale       linear         0.828333
# 18      10        auto          rbf         0.547895
# 19      10        auto       linear         0.828333

# %%
gs.best_params_
# Out:
# {'C': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %%
gs.best_score_
# Out:
# 0.8480263157894736

# %% [markdown]
# ###
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import GridSearchCV
# gs = GridSearchCV(SVC(),
#                  {
#                      'C':[1,2,5,9,10],
#                      'kernel':['rbf','linear'],
#                      'gamma':['scale','auto']
#                  }, cv=4,return_train_score=False)
# gs.fit(X,y)
#
# gs.cv_results_
# df1 = pd.DataFrame(gs.cv_results_)
# df1
# df1[['param_C','param_gamma','param_kernel','mean_test_score']]
# gs.best_params_
# gs.best_score_

# %% [markdown]
# ## Random-Search-CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rs = RandomizedSearchCV(SVC(),
                 {
                     'C':[1,2,5,9,10],
                     'kernel':['rbf','poly'],
                     'gamma':['scale','auto']
                 }, cv=4,return_train_score=True,n_iter=3)
rs.fit(X,y)

# %%
rs.cv_results_

# %%
df2 = pd.DataFrame(gs.cv_results_)
df2

# %%
df2[['param_C','param_gamma','param_kernel','mean_test_score']]
#gs.best_params_
#gs.best_score_

# %%
#df1[['param_C','param_gamma','param_kernel','mean_test_score']]
gs.best_params_
#gs.best_score_

# %%
#df1[['param_C','param_gamma','param_kernel','mean_test_score']]
#gs.best_params_
gs.best_score_
